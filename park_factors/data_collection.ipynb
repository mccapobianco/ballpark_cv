# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
import re

# %% [markdown]
# # AAA

# %%
# https://www.milb.com/stats/team

def read_clipboard_aaa():
    df = pd.DataFrame(pd.read_clipboard(delimiter=chr(1), header=None).values.reshape((-1,3)))
    df = pd.concat([df,df.loc[:,2].str.split('\t', expand=True)], axis=1, ignore_index=True)
    df = df.drop(2, axis=1)
    df.columns = ['rank','team','league','g','ab','r','h','2b','3b','hr',
                  'rbi','bb','so','sb','cs','avg','obp','slg','ops']
    return df

# %%
def read_clipboard_aaa_pitching():
    df = pd.DataFrame(pd.read_clipboard(delimiter=chr(1), header=None).values.reshape((-1,3)))
    df = pd.concat([df,df.loc[:,2].str.split('\t', expand=True)], axis=1, ignore_index=True)
    df = df.drop(2, axis=1)
    df.columns = ['rank','team','league','w','l','era','g','gs','cg','sho','sv','svo','ip','h',
                  'r','er','hr','hb','bb','so','whip','avg']
    return df

# %%
il_h = read_clipboard_aaa()

# %%
il_a = read_clipboard_aaa()

# %%
pcl_a = read_clipboard_aaa()

# %%
pcl_h = read_clipboard_aaa()

# %%
il_hp = read_clipboard_aaa_pitching()

# %%
il_ap = read_clipboard_aaa_pitching()

# %%
pcl_hp = read_clipboard_aaa_pitching()

# %%
pcl_ap = read_clipboard_aaa_pitching()

# %%
pcl = pd.merge(pcl_h, pcl_a, on=['team','league'], suffixes=('_home', '_away'))
il = pd.merge(il_h, il_a, on=['team','league'], suffixes=('_home','_away'))
aaa = pd.concat([pcl, il], ignore_index=True)

# %%
pclp = pd.merge(pcl_hp, pcl_ap, on=['team','league'], suffixes=('_home', '_away'))
ilp = pd.merge(il_hp, il_ap, on=['team','league'], suffixes=('_home','_away'))
aaap = pd.concat([pclp, ilp], ignore_index=True)

# %%
aaa = pd.merge(aaa, aaap, on=['team','league'], suffixes=('','_against'))

# %%
for col in aaa.columns:
    if col not in ['team','league']:
        aaa[col] = pd.to_numeric(aaa[col])

# %%
aaa['r/g_home'] = (aaa['r_home'] + aaa['r_home_against']) / (aaa['g_home'])
aaa['r/g_away'] = (aaa['r_away'] + aaa['r_away_against']) / (aaa['g_away'])

# %%
aaa['park_factor'] = aaa['r/g_home'] / aaa['r/g_away']

# %%
aaa[['team','park_factor']].sort_values('park_factor')
# Out:
#              team  park_factor
# 6      Sacramento     0.637000
# 5      Okla. City     0.777652
# 7      Sugar Land     0.799716
# 22        Norfolk     0.805587
# 29      Nashville     0.837736
# 24      Rochester     0.849461
# 25        Buffalo     0.895487
# 27         Toledo     0.895758
# 12         Durham     0.899272
# 28       Gwinnett     0.913972
# 8      Round Rock     0.938750
# 23   Jacksonville     0.970917
# 18      Worcester     0.987775
# 26   Indianapolis     0.988059
# 21     Louisville     1.003189
# 9       Salt Lake     1.017233
# 11       Columbus     1.028842
# 17        Memphis     1.036716
# 2          Tacoma     1.052443
# 13          Omaha     1.067235
# 14  Lehigh Valley     1.076182
# 0       Las Vegas     1.105246
# 10       Syracuse     1.112315
# 20      Charlotte     1.125234
# 15       St. Paul     1.138265
# 19    Scranton/WB     1.164947
# 4         El Paso     1.221795
# 1            Reno     1.266567
# 3     Albuquerque     1.293567
# 16           Iowa     1.361669

# %%
aaa_parks = {'Jacksonville':'vystar_ballpark', 'Memphis': 'autozone_park', 'St. Paul': 'chs_field',
              'Lehigh Valley': 'coca_cola_park', 'Gwinnett': 'coolray_field', 'Durham': 'durham_bulls_athletic_park',
                'Toledo': 'fifth_third_field', 'Nashville': 'first_horizon_park', 'Norfolk': 'harbor_park', 
                'Columbus': 'huntington_park', 'Rochester': 'innovative_field', 'Louisville': 'louisville_slugger_field',
                  'Syracuse': 'nbt_bank_stadium', 'Scranton/WB': 'pnc_field', 'Worcester': 'polar_park', 
                  'Iowa': 'principal_park', 'Buffalo': 'sahlen_field', 'Charlotte': 'truist_field', 
                  'Indianapolis': 'victory_field', 'Omaha': 'werner_park',
                  'Tacoma': 'cheney_stadium', 'Okla. City': 'chickasaw_bricktown_ballpark', 
                  'Sugar Land': 'constellation_field', 'Salt Lake': 'smiths_ballpark', 
                  'Round Rock': 'dell_diamond', 'Reno': 'greater_nevada_field', 'Las Vegas': 'las_vegas_ballpark', 
                  'Albuquerque': 'rio_grande_credit_union_field_at_isotopes_park', 'El Paso': 'southwest_university_park',
                  'Sacramento': 'sutter_health_park'}

# %%
import json
with open('../data_collection/metadata.json','r') as f:
    metadata = json.load(f)

# %%
for k,v in aaa_parks.items():
    if k not in aaa['team'].values:
        print('Team:', k)
    if v not in metadata:
        print('Park:',v)

# %%
aaa['ballpark'] = aaa['team'].apply(aaa_parks.get)

# %%
aaa[['ballpark','park_factor','g_home']].to_csv('aaa_park_factors.csv', index=False)

# %% [markdown]
# # NPB

# %%
games = []
for team in ['t','c','db','g','s','d','b','m','h','e','l','f']:
    for month in range(4,11):

        response = requests.get(f"https://npb.jp/bis/eng/teams/calendar_{team}_{str(month).zfill(2)}.html")
        soup = BeautifulSoup(response.text, features='lxml')
        calendar = soup.find('table', {'class':'tetblmain'})
        for tr in calendar.find_all('tr')[1:]:
            for td in tr.find_all('td'):
                postseason = False
                for title in ['CS First Stage','CS Final Stage','Nippon Series','Postponed','No Game']:
                    if title in td.text:
                        postseason = True
                if not postseason:
                    game = td.find_all('div',{'class':'tevsteam'})
                    if game:
                        game = game[0]
                        date = td.find('div',{'class':'teschedate'}).text
                        score = game.find('div',{'class':'tescore'})
                        stadium = game.find('div',{'class':'testdm'}).text[1:-1]
                        home_team, home_score, _, away_score, away_team = score.text.split(' ')
                        game_id = score.find('a')['href'].split('/')[-1].split('.')[0]
                        games.append({'home_team':home_team, 'home_score':int(home_score), 'away_team':away_team,
                                      'away_score':int(away_score), 'stadium':stadium, 'game_id':game_id})

# %%
npb_df = pd.DataFrame(games).drop_duplicates(subset='game_id').set_index('game_id')
npb_df.head()
# Out:
#                home_team  home_score away_team  away_score       stadium
# game_id
# s2024032901088         G           4         T           0    Tokyo Dome
# s2024033001091         G           5         T           0    Tokyo Dome
# s2024033101094         G           0         T           5    Tokyo Dome
# s2024040201098         T           3        DB           5  Kyocera Dome
# s2024040301101         T           5        DB           2  Kyocera Dome

# %%
npb_df['game_count'] = 1
npb_df['total_score'] = npb_df['home_score'] + npb_df['away_score']

# %%
npb_df.head()
# Out:
#                home_team  home_score away_team  away_score       stadium  \
# game_id
# s2024032901088         G           4         T           0    Tokyo Dome
# s2024033001091         G           5         T           0    Tokyo Dome
# s2024033101094         G           0         T           5    Tokyo Dome
# s2024040201098         T           3        DB           5  Kyocera Dome
# s2024040301101         T           5        DB           2  Kyocera Dome
#
#                 game_count  total_score
# game_id
# s2024032901088           1            4
# s2024033001091           1            5
# s2024033101094           1            5
# s2024040201098           1            8
# s2024040301101           1            7

# %%
npb_home = npb_df.groupby(['home_team','stadium'])[['total_score','game_count']].sum().reset_index()
npb_away = npb_df.groupby(['away_team'])[['total_score','game_count']].sum().reset_index()
npb = pd.merge(npb_home, npb_away, left_on='home_team', right_on='away_team', suffixes=('_home','_away'))
npb.pop('away_team')
npb = npb.rename(columns={'home_team':'team'})
npb
# Out:
#    team           stadium  total_score_home  game_count_home  \
# 0     B        Hotto Kobe                51                8
# 1     B      Kyocera Dome               349               61
# 2     B              Naha                 7                2
# 3     C     Mazda Stadium               430               71
# 4     D              Gifu                 8                1
# 5     D         Toyohashi                 6                1
# 6     D     Vantelin Dome               362               69
# 7    DB  HARD OFF Niigata                 5                1
# 8    DB          Yokohama               532               71
# 9     E             Akita                 5                1
# 10    E         Fukushima                 8                1
# 11    E          Hirosaki                 5                1
# 12    E    Rakuten Mobile               448               66
# 13    E        Tokyo Dome                 7                1
# 14    E          Yamagata                 4                1
# 15    F      ES CON FIELD               566               72
# 16    G             Fukui                 4                1
# 17    G              Gifu                 3                1
# 18    G       Hitachinaka                 2                1
# 19    G      Kyocera Dome                10                2
# 20    G          Maebashi                 7                1
# 21    G         Matsumoto                 3                1
# 22    G        Tokyo Dome               385               64
# 23    G            Toyama                 3                1
# 24    H        Kitakyushu                22                2
# 25    H          Kumamoto                 6                1
# 26    H      Kyocera Dome                12                1
# 27    H     MIZUHO PayPay               411               59
# 28    H          Miyazaki                 5                1
# 29    H          Nagasaki                 5                1
# 30    H       PayPay Dome                43                6
# 31    H        Tokyo Dome                 5                1
# 32    L      Belluna Dome               411               69
# 33    L          Maebashi                 1                1
# 34    L             Omiya                 9                2
# 35    M       ZOZO Marine               510               71
# 36    S             Jingu               559               68
# 37    S         Kagoshima                 4                1
# 38    S         Matsuyama                 5                2
# 39    T           Koshien               349               62
# 40    T         Kurashiki                 1                1
# 41    T      Kyocera Dome                71                9
#
#     total_score_away  game_count_away
# 0                443               72
# 1                443               72
# 2                443               72
# 3                404               72
# 4                475               72
# 5                475               72
# 6                475               72
# 7                488               71
# 8                488               71
# 9                594               72
# 10               594               72
# 11               594               72
# 12               594               72
# 13               594               72
# 14               594               72
# 15               451               71
# 16               426               71
# 17               426               71
# 18               426               71
# 19               426               71
# 20               426               71
# 21               426               71
# 22               426               71
# 23               426               71
# 24               488               71
# 25               488               71
# 26               488               71
# 27               488               71
# 28               488               71
# 29               488               71
# 30               488               71
# 31               488               71
# 32               414               71
# 33               414               71
# 34               414               71
# 35               478               72
# 36               494               72
# 37               494               72
# 38               494               72
# 39               484               71
# 40               484               71
# 41               484               71

# %%
npb[npb['stadium'].duplicated(False)].sort_values('stadium')
# Out:
#    team       stadium  total_score_home  game_count_home  total_score_away  \
# 4     D          Gifu                 8                1               475
# 17    G          Gifu                 3                1               426
# 1     B  Kyocera Dome               349               61               443
# 19    G  Kyocera Dome                10                2               426
# 26    H  Kyocera Dome                12                1               488
# 41    T  Kyocera Dome                71                9               484
# 20    G      Maebashi                 7                1               426
# 33    L      Maebashi                 1                1               414
# 13    E    Tokyo Dome                 7                1               594
# 22    G    Tokyo Dome               385               64               426
# 31    H    Tokyo Dome                 5                1               488
#
#     game_count_away
# 4                72
# 17               71
# 1                72
# 19               71
# 26               71
# 41               71
# 20               71
# 33               71
# 13               72
# 22               71
# 31               71

# %%
npb_stadiums = npb.groupby('stadium').sum().reset_index()
npb_stadiums.head()
# Out:
#         stadium  total_score_home  game_count_home  total_score_away  \
# 0         Akita                 5                1               594
# 1  Belluna Dome               411               69               414
# 2  ES CON FIELD               566               72               451
# 3         Fukui                 4                1               426
# 4     Fukushima                 8                1               594
#
#    game_count_away
# 0               72
# 1               71
# 2               71
# 3               71
# 4               72

# %%
npb_stadiums['park_factor'] = (npb_stadiums['total_score_home'] / npb_stadiums['game_count_home']) / \
                                (npb_stadiums['total_score_away'] / npb_stadiums['game_count_away'])

# %%
npb_pf = npb_stadiums.rename(columns={'game_count_home':'g_home', 'stadium':'ballpark'})
#TODO fix stadium names
npb_pf[['ballpark','park_factor','g_home']].to_csv('npb_park_factors_raw.csv', index=False)

# %%
npb.query('stadium=="Hotto Kobe"')
# Out:
#    team           stadium  total_score_home  game_count_home  \
# 0     B        Hotto Kobe                51                8
# 1     B      Kyocera Dome               349               61
# 2     B              Naha                 7                2
# 3     C     Mazda Stadium               430               71
# 4     D              Gifu                 8                1
# 5     D         Toyohashi                 6                1
# 6     D     Vantelin Dome               362               69
# 7    DB  HARD OFF Niigata                 5                1
# 8    DB          Yokohama               532               71
# 9     E             Akita                 5                1
# 10    E         Fukushima                 8                1
# 11    E          Hirosaki                 5                1
# 12    E    Rakuten Mobile               448               66
# 13    E        Tokyo Dome                 7                1
# 14    E          Yamagata                 4                1
# 15    F      ES CON FIELD               566               72
# 16    G             Fukui                 4                1
# 17    G              Gifu                 3                1
# 18    G       Hitachinaka                 2                1
# 19    G      Kyocera Dome                10                2
# 20    G          Maebashi                 7                1
# 21    G         Matsumoto                 3                1
# 22    G        Tokyo Dome               385               64
# 23    G            Toyama                 3                1
# 24    H        Kitakyushu                22                2
# 25    H          Kumamoto                 6                1
# 26    H      Kyocera Dome                12                1
# 27    H     MIZUHO PayPay               411               59
# 28    H          Miyazaki                 5                1
# 29    H          Nagasaki                 5                1
# 30    H       PayPay Dome                43                6
# 31    H        Tokyo Dome                 5                1
# 32    L      Belluna Dome               411               69
# 33    L          Maebashi                 1                1
# 34    L             Omiya                 9                2
# 35    M       ZOZO Marine               510               71
# 36    S             Jingu               559               68
# 37    S         Kagoshima                 4                1
# 38    S         Matsuyama                 5                2
# 39    T           Koshien               349               62
# 40    T         Kurashiki                 1                1
# 41    T      Kyocera Dome                71                9
#
#     total_score_away  game_count_away
# 0                443               72
# 1                443               72
# 2                443               72
# 3                404               72
# 4                475               72
# 5                475               72
# 6                475               72
# 7                488               71
# 8                488               71
# 9                594               72
# 10               594               72
# 11               594               72
# 12               594               72
# 13               594               72
# 14               594               72
# 15               451               71
# 16               426               71
# 17               426               71
# 18               426               71
# 19               426               71
# 20               426               71
# 21               426               71
# 22               426               71
# 23               426               71
# 24               488               71
# 25               488               71
# 26               488               71
# 27               488               71
# 28               488               71
# 29               488               71
# 30               488               71
# 31               488               71
# 32               414               71
# 33               414               71
# 34               414               71
# 35               478               72
# 36               494               72
# 37               494               72
# 38               494               72
# 39               484               71
# 40               484               71
# 41               484               71

# %% [markdown]
# # KBO

# %%
response = requests.get('https://mykbostats.com/stats/team_splits/2024')
# dfs = pd.read_html(response.text)
soup = BeautifulSoup(response.text, features='lxml')
tables = soup.find_all('table', {'class':'team-splits ui compact very basic sortable unstackable hsticky table'})

# %%
def get_stats_clipboard_kbo():
    df = pd.read_clipboard()
    home = df.iloc[:10,:].reset_index()
    away = df.iloc[-10:,:].reset_index()
    for d in [home, away]:
        for c in ['R','-R','G']:
            d[c] = pd.to_numeric(d[c])
    home['total_runs_per_game'] = (home['R'] + home['-R']) / home['G']
    away['total_runs_per_game'] = (away['R'] + away['-R']) / away['G']
    home.columns = ['Location','Team'] + home.columns.tolist()[2:]
    away.columns = home.columns
    kbo = pd.merge(home, away, on=['Location','Team'], suffixes=('_home','_away'))
    kbo['park_factor'] = kbo['total_runs_per_game_home'] / kbo['total_runs_per_game_away']
    kbo['ballpark'] = kbo['Location'].str.cat(kbo['Team'], sep=' ').apply({'LG Twins':'mokdong_baseball_stadium','Doosan Bears':'mokdong_baseball_stadium','Lotte Giants':'sajik_baseball_stadium',
                                                                    'Samsung Lions':'daegu_samsung_lions_park', 'SSG Landers':'incheon_ssg_landers_field', 'NC Dinos':'changwon_nc_park',
                                                                    'Kia Tigers':'kia_champions_field', 'KT Wiz':'suwon_kt_wiz_park','Hanwha Eagles':'cheongju_baseball_stadium','Kiwoom Heroes':'gocheok_sky_dome'}.get)
    kbo = kbo.rename(columns={'G_home':'g_home'})
    return kbo['ballpark,park_factor,g_home'.split(',')].dropna()

kbo = get_stats_clipboard_kbo()
kbo
# Out:
#                     ballpark  park_factor  g_home
# 0        kia_champions_field     1.023923      76
# 1   daegu_samsung_lions_park     1.150833      77
# 2   mokdong_baseball_stadium     0.933258      78
# 3   mokdong_baseball_stadium     0.885086      73
# 4          suwon_kt_wiz_park     1.028408      74
# 5  incheon_ssg_landers_field     1.182258      71
# 6     sajik_baseball_stadium     1.138330      71
# 7  cheongju_baseball_stadium     0.976892      71
# 8           changwon_nc_park     0.903472      73
# 9           gocheok_sky_dome     0.827877      73

# %%
kbo.to_csv('kbo_park_factors.csv', index=False)

# %%
{'LG Twins':'mokdong_baseball_stadium','Doosan Bears':'mokdong_baseball_stadium','Lotte Giants':'sajik_baseball_stadium',
 'Samsung Lions':'daegu_samsung_lions_park', 'SSG Landers':'incheon_ssg_landers_field', 'NC Dinos':'changwon_nc_park',
 'KIA Tigers':'kia_champions_field', 'KT Wiz':'suwon_kt_wiz_park','Hanwha Eagles':'cheongju_baseball_stadium'}

# %% [markdown]
# # MLB

# %%
mlb = pd.read_clipboard()
mlb
# Out:
#     Rk.        Team                        Venue       Year  Park Factor  \
# 0     1     Rockies                  Coors Field  2022-2024          112
# 1     2     Red Sox                  Fenway Park  2022-2024          107
# 2     3        Reds     Great American Ball Park  2022-2024          105
# 3     4      Royals             Kauffman Stadium  2022-2024          104
# 4     5       Twins                 Target Field  2022-2024          102
# 5     6     D-backs                  Chase Field  2022-2024          101
# 6     7     Pirates                     PNC Park  2022-2024          101
# 7     8     Marlins               loanDepot park  2022-2024          101
# 8     9    Phillies           Citizens Bank Park  2022-2024          101
# 9    10     Rangers             Globe Life Field  2022-2024          101
# 10   11   Nationals               Nationals Park  2022-2024          101
# 11   12      Angels                Angel Stadium  2022-2024          100
# 12   13   Blue Jays                Rogers Centre  2022-2024          100
# 13   14     Dodgers               Dodger Stadium  2022-2024          100
# 14   15   Cardinals                Busch Stadium  2022-2024          100
# 15   16      Astros             Minute Maid Park  2022-2024          100
# 16   17      Braves                  Truist Park  2022-2024          100
# 17   18     Yankees               Yankee Stadium  2022-2024          100
# 18   19     Orioles  Oriole Park at Camden Yards  2022-2024           99
# 19   20   White Sox        Guaranteed Rate Field  2022-2024           99
# 20   21      Tigers                Comerica Park  2022-2024           98
# 21   22   Guardians            Progressive Field  2022-2024           97
# 22   23   Athletics             Oakland Coliseum  2022-2024           97
# 23   24        Cubs                Wrigley Field  2022-2024           97
# 24   25     Brewers        American Family Field  2022-2024           97
# 25   26      Giants                  Oracle Park  2022-2024           97
# 26   27        Mets                   Citi Field  2022-2024           97
# 27   28        Rays              Tropicana Field  2022-2024           96
# 28   29      Padres                   Petco Park  2022-2024           96
# 29   30    Mariners                T-Mobile Park  2022-2024           91
#
#     wOBACon  xwOBACon  BACON  xBACON  HardHit    R  OBP    H   1B   2B   3B  \
# 0       111       102    111     103      103  125  110  116  115  118  198
# 1       107       102    108     101      103  114  106  109  107  123  118
# 2       106        99    103      99       96  110  103  102   98  100   79
# 3       100       103    102     102      105  108  105  106  107  114  168
# 4       104       102    103     100      101  104  102  101   98  107   90
# 5       100        99    101     100      101  102  102  104  104  113  168
# 6        99       101    101     101      103  102  103  102  104  110   80
# 7       102       101    102     101      100  102  102  103  104  109  117
# 8       103       100    101      99      100  102   99  100   98   98  107
# 9       101       101     99     100      102  102  100  100   98   96   90
# 10       98       100     99     100       99  102  101  102  105   98   85
# 11      102       101    100     100       98  100  100   98   98   90  102
# 12      100        99     99     100      101  100  100  101   98  109   70
# 13      100       100     97      99      100  100   97   97   92   97   74
# 14       97       101     99     101      101  100  101  102  105  102   95
# 15      101        99    100      99       98  100  100  100   99   98   88
# 16      104       105    104     103      105  100  100  102  103   95   87
# 17      100       103     97     101      102  100   99   94   91   91   51
# 18       99       102    101     102      104   98  100  103  108   94  109
# 19       99        98    100      98       97   98  100  100  103   94   62
# 20       96        99     98     100      100   96   99   98  102   92  146
# 21       96        97     98      99       96   94   98   99   99  107   69
# 22       95        96     97      97       95   94   99   97   97  107  104
# 23       98        98     98      99       97   94   98   98  101   89  131
# 24      100       101     97     100       97   94   96   94   91   87   93
# 25       97        98     99      99      102   94   98  100  103  104  125
# 26       96        99     96      98       99   94   98   92   93   86   72
# 27       98        98     98      98       96   92   96   96   94   96  114
# 28       96       100     96      99      100   92   97   96   97   90   55
# 29       94        98     94      98       96   83   92   90   91   85   59
#
#      HR   BB   SO      PA
# 0   109   99   89  56,537
# 1    98   96   97  57,350
# 2   128  105  102  56,113
# 3    85  102   87  56,788
# 4   105  105  105  56,874
# 5    86   99   94  57,491
# 6    84  102   95  56,717
# 7    92   96  100  56,832
# 8   115   96  102  59,030
# 9   115  103  100  57,150
# 10  101   96   89  55,170
# 11  112  103  106  55,854
# 12  103   97   98  56,362
# 13  122   98  101  59,029
# 14   91   99   90  55,932
# 15  107  102  101  57,080
# 16  105   98  109  56,162
# 17  119  110  103  59,223
# 18   93   93   96  55,857
# 19   98  101  100  57,822
# 20   86   98   97  55,344
# 21   86   97   98  56,438
# 22   81  102   98  55,403
# 23   93  102  103  55,217
# 24  114  106  112  57,190
# 25   78   92   99  55,227
# 26   99  110  104  58,441
# 27   98   95  108  55,802
# 28  104   99  102  58,146
# 29   96   95  115  55,886

# %%
mlb['ballpark'] = mlb['Venue'].apply(lambda x : x.lower().replace(' ','_').replace('-','_')).replace({'great_american_ball_park':'great_american_ballpark','angel_stadium':'angels_stadium','oriole_park_at_camden_yards':'camden_yards'})

# %%
mlb
# Out:
#     Rk.        Team                        Venue       Year  Park Factor  \
# 0     1     Rockies                  Coors Field  2022-2024          112
# 1     2     Red Sox                  Fenway Park  2022-2024          107
# 2     3        Reds     Great American Ball Park  2022-2024          105
# 3     4      Royals             Kauffman Stadium  2022-2024          104
# 4     5       Twins                 Target Field  2022-2024          102
# 5     6     D-backs                  Chase Field  2022-2024          101
# 6     7     Pirates                     PNC Park  2022-2024          101
# 7     8     Marlins               loanDepot park  2022-2024          101
# 8     9    Phillies           Citizens Bank Park  2022-2024          101
# 9    10     Rangers             Globe Life Field  2022-2024          101
# 10   11   Nationals               Nationals Park  2022-2024          101
# 11   12      Angels                Angel Stadium  2022-2024          100
# 12   13   Blue Jays                Rogers Centre  2022-2024          100
# 13   14     Dodgers               Dodger Stadium  2022-2024          100
# 14   15   Cardinals                Busch Stadium  2022-2024          100
# 15   16      Astros             Minute Maid Park  2022-2024          100
# 16   17      Braves                  Truist Park  2022-2024          100
# 17   18     Yankees               Yankee Stadium  2022-2024          100
# 18   19     Orioles  Oriole Park at Camden Yards  2022-2024           99
# 19   20   White Sox        Guaranteed Rate Field  2022-2024           99
# 20   21      Tigers                Comerica Park  2022-2024           98
# 21   22   Guardians            Progressive Field  2022-2024           97
# 22   23   Athletics             Oakland Coliseum  2022-2024           97
# 23   24        Cubs                Wrigley Field  2022-2024           97
# 24   25     Brewers        American Family Field  2022-2024           97
# 25   26      Giants                  Oracle Park  2022-2024           97
# 26   27        Mets                   Citi Field  2022-2024           97
# 27   28        Rays              Tropicana Field  2022-2024           96
# 28   29      Padres                   Petco Park  2022-2024           96
# 29   30    Mariners                T-Mobile Park  2022-2024           91
#
#     wOBACon  xwOBACon  BACON  xBACON  HardHit  ...  OBP    H   1B   2B   3B  \
# 0       111       102    111     103      103  ...  110  116  115  118  198
# 1       107       102    108     101      103  ...  106  109  107  123  118
# 2       106        99    103      99       96  ...  103  102   98  100   79
# 3       100       103    102     102      105  ...  105  106  107  114  168
# 4       104       102    103     100      101  ...  102  101   98  107   90
# 5       100        99    101     100      101  ...  102  104  104  113  168
# 6        99       101    101     101      103  ...  103  102  104  110   80
# 7       102       101    102     101      100  ...  102  103  104  109  117
# 8       103       100    101      99      100  ...   99  100   98   98  107
# 9       101       101     99     100      102  ...  100  100   98   96   90
# 10       98       100     99     100       99  ...  101  102  105   98   85
# 11      102       101    100     100       98  ...  100   98   98   90  102
# 12      100        99     99     100      101  ...  100  101   98  109   70
# 13      100       100     97      99      100  ...   97   97   92   97   74
# 14       97       101     99     101      101  ...  101  102  105  102   95
# 15      101        99    100      99       98  ...  100  100   99   98   88
# 16      104       105    104     103      105  ...  100  102  103   95   87
# 17      100       103     97     101      102  ...   99   94   91   91   51
# 18       99       102    101     102      104  ...  100  103  108   94  109
# 19       99        98    100      98       97  ...  100  100  103   94   62
# 20       96        99     98     100      100  ...   99   98  102   92  146
# 21       96        97     98      99       96  ...   98   99   99  107   69
# 22       95        96     97      97       95  ...   99   97   97  107  104
# 23       98        98     98      99       97  ...   98   98  101   89  131
# 24      100       101     97     100       97  ...   96   94   91   87   93
# 25       97        98     99      99      102  ...   98  100  103  104  125
# 26       96        99     96      98       99  ...   98   92   93   86   72
# 27       98        98     98      98       96  ...   96   96   94   96  114
# 28       96       100     96      99      100  ...   97   96   97   90   55
# 29       94        98     94      98       96  ...   92   90   91   85   59
#
#      HR   BB   SO      PA                 ballpark
# 0   109   99   89  56,537              coors_field
# 1    98   96   97  57,350              fenway_park
# 2   128  105  102  56,113  great_american_ballpark
# 3    85  102   87  56,788         kauffman_stadium
# 4   105  105  105  56,874             target_field
# 5    86   99   94  57,491              chase_field
# 6    84  102   95  56,717                 pnc_park
# 7    92   96  100  56,832           loandepot_park
# 8   115   96  102  59,030       citizens_bank_park
# 9   115  103  100  57,150         globe_life_field
# 10  101   96   89  55,170           nationals_park
# 11  112  103  106  55,854           angels_stadium
# 12  103   97   98  56,362            rogers_centre
# 13  122   98  101  59,029           dodger_stadium
# 14   91   99   90  55,932            busch_stadium
# 15  107  102  101  57,080         minute_maid_park
# 16  105   98  109  56,162              truist_park
# 17  119  110  103  59,223           yankee_stadium
# 18   93   93   96  55,857             camden_yards
# 19   98  101  100  57,822    guaranteed_rate_field
# 20   86   98   97  55,344            comerica_park
# 21   86   97   98  56,438        progressive_field
# 22   81  102   98  55,403         oakland_coliseum
# 23   93  102  103  55,217            wrigley_field
# 24  114  106  112  57,190    american_family_field
# 25   78   92   99  55,227              oracle_park
# 26   99  110  104  58,441               citi_field
# 27   98   95  108  55,802          tropicana_field
# 28  104   99  102  58,146               petco_park
# 29   96   95  115  55,886            t_mobile_park
#
# [30 rows x 21 columns]

# %%
for s in mlb['ballpark'].values.tolist():
    if s not in metadata:
        print(s)
# Out:
# chase_field
# loandepot_park
# globe_life_field
# rogers_centre
# minute_maid_park
# tropicana_field
# tmobile_park

# %%
mlb['Park Factor']
# Out:
# 0     112
# 1     107
# 2     105
# 3     104
# 4     102
# 5     101
# 6     101
# 7     101
# 8     101
# 9     101
# 10    101
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 18     99
# 19     99
# 20     98
# 21     97
# 22     97
# 23     97
# 24     97
# 25     97
# 26     97
# 27     96
# 28     96
# 29     91
# Name: Park Factor, dtype: int64

# %%
mlb['park_factor'] = mlb['Park Factor']
mlb['pa'] = pd.to_numeric(mlb['PA'].str.replace(',',''))

# %%
mlb[['ballpark','park_factor','pa']].to_csv('mlb_park_factors.csv', index=False)

# %% [markdown]
# # combine

# %%
combined = pd.concat([pd.read_csv(f'{x}_park_factors.csv').assign(lg=x) for x in ['aaa','kbo','npb','mlb']])

# %%
combined
# Out:
#                                           ballpark  park_factor  g_home   lg  \
# 0                               las_vegas_ballpark     1.105246    75.0  aaa
# 1                             greater_nevada_field     1.266567    74.0  aaa
# 2                                   cheney_stadium     1.052443    75.0  aaa
# 3   rio_grande_credit_union_field_at_isotopes_park     1.293567    75.0  aaa
# 4                        southwest_university_park     1.221795    75.0  aaa
# ..                                             ...          ...     ...  ...
# 25                                     oracle_park    97.000000     NaN  mlb
# 26                                      citi_field    97.000000     NaN  mlb
# 27                                 tropicana_field    96.000000     NaN  mlb
# 28                                      petco_park    96.000000     NaN  mlb
# 29                                   t_mobile_park    91.000000     NaN  mlb
#
#          pa
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 25  55227.0
# 26  58441.0
# 27  55802.0
# 28  58146.0
# 29  55886.0
#
# [77 rows x 5 columns]

# %%
combined = combined[combined['ballpark'].apply(lambda x:x in metadata)]

# %%
combined
# Out:
#                                           ballpark  park_factor  g_home   lg  \
# 0                               las_vegas_ballpark     1.105246    75.0  aaa
# 1                             greater_nevada_field     1.266567    74.0  aaa
# 2                                   cheney_stadium     1.052443    75.0  aaa
# 3   rio_grande_credit_union_field_at_isotopes_park     1.293567    75.0  aaa
# 4                        southwest_university_park     1.221795    75.0  aaa
# ..                                             ...          ...     ...  ...
# 23                                   wrigley_field    97.000000     NaN  mlb
# 24                           american_family_field    97.000000     NaN  mlb
# 25                                     oracle_park    97.000000     NaN  mlb
# 26                                      citi_field    97.000000     NaN  mlb
# 28                                      petco_park    96.000000     NaN  mlb
#
#          pa
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 23  55217.0
# 24  57190.0
# 25  55227.0
# 26  58441.0
# 28  58146.0
#
# [69 rows x 5 columns]

# %%
obstructions = pd.read_csv('../data_collection/obstructed_fields.txt').rename(columns={'name':'ballpark',' obstruction_type':'obstruction_type'})

# %%
obstructions['obstruction_type'] = obstructions['obstruction_type'].str.strip()

# %%
combined = pd.merge(combined, obstructions, on='ballpark', how='left')

# %%
combined
# Out:
#                                           ballpark  park_factor  g_home   lg  \
# 0                               las_vegas_ballpark     1.105246    75.0  aaa
# 1                             greater_nevada_field     1.266567    74.0  aaa
# 2                                   cheney_stadium     1.052443    75.0  aaa
# 3   rio_grande_credit_union_field_at_isotopes_park     1.293567    75.0  aaa
# 4                        southwest_university_park     1.221795    75.0  aaa
# ..                                             ...          ...     ...  ...
# 64                                   wrigley_field    97.000000     NaN  mlb
# 65                           american_family_field    97.000000     NaN  mlb
# 66                                     oracle_park    97.000000     NaN  mlb
# 67                                      citi_field    97.000000     NaN  mlb
# 68                                      petco_park    96.000000     NaN  mlb
#
#          pa   obstruction_type
# 0       NaN                NaN
# 1       NaN                NaN
# 2       NaN                NaN
# 3       NaN                NaN
# 4       NaN  structural_shadow
# ..      ...                ...
# 64  55217.0                NaN
# 65  57190.0         structural
# 66  55227.0                NaN
# 67  58441.0                NaN
# 68  58146.0                NaN
#
# [69 rows x 6 columns]

# %%
combined.to_csv('all_park_factors.csv', index=False)

# %%
combined['obstruction_type'].isnull().sum()
# Out:
# 53
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
